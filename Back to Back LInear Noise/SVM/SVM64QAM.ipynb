# %% [markdown]
# # 64 QAM DSP ML SVM

# %%
# %pylab inline
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd QAM6bit/
# Out:
# C:\Users\ChiefGuti\Documents\Lund University\Thesis\MLImplementacion\QAM6bit

# %% [markdown]
# ## Load  Data

# %%
data = loadtxt('OutRx_DualPol6bOSNR20R6.txt',delimiter=';')
Code=loadtxt('PBRSout.txt',skiprows=5)

# %% [markdown]
# # Functions

# %%
def NormData(DataSet,data):
    for i in range(len(data[:,0])):
        DataSet[i,0]=data[:,0][i]
        DataSet[i,1]=data[:,1][i]
    DataSet[:,0]=DataSet[:,0]/max(DataSet[:,0])
    DataSet[:,1]=DataSet[:,1]/max(DataSet[:,1])

# %%
def ColorMap(Word,Map,M):
    Cmap=arange(M)
    for i in range(len(Word)):
        for j in range(len(Cmap)):
            if(Word[i]==Org[j]):
                Map[i]=Cmap[j]

# %%
def BER(x,y):
    j=0
    for i in range(len(x)):
        if(x[i]!=y[i]):
            j+=1
    return(j/len(x))

# %% [markdown]
# ## Training data

# %%
scatter(data[:,0]/max(data[:,0]),data[:,1]/max(data[:,1]),s=1)

# %% [markdown]
# ### Simple splice DSP

# %%
done=data[1::2][:]
shape(done)
# Out:
# (32768, 4)

# %%
data=done
scatter(data[:,0]/max(data[:,0]),data[:,1]/max(data[:,1]),s=1)

# %% [markdown]
# ## PBRS reformating

# %% [markdown]
# ### Retrive PBRS creat Classification vector

# %%
INT=[]
for i in range(int(len(Code)/6)):
    INT.append(i*6)
CodeWord=[]
for i in range(len(Code)):
    CodeWord.append(str(int(Code[i])))

Word=[]
Org=[]
j=0
for i in INT:
    Word.append(CodeWord[i]+CodeWord[i+1]+CodeWord[i+2]+CodeWord[i+3]+CodeWord[i+4]+CodeWord[i+5])
    
    if((Word[j] in Org)==False ):
        Org.append(Word[j])
    j=j+1

# %%
len(Org)
# Out:
# 64

# %%
Map=zeros(len(Word))
ColorMap(Word,Map,64)

# %% [markdown]
# ## Complete Incoming Data

# %%
#Normalize IQ data after splice
DataSet=zeros((len(data[:,0]),2))
NormData(DataSet,data)

# %%
scatter(DataSet[:,0],DataSet[:,1],c=Map,s=1)
colorbar()
grid(True)

# %% [markdown]
# ## ML training SVM

# %%
X_train, X_test, y_train, y_test = train_test_split(DataSet, Map, test_size = 0.20)

# %%
svclassifier = SVC(kernel='rbf',C=1)
svclassifier.fit(X_train, y_train)
# Out:
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# ### Testing data set

# %%
# Set the parameters by cross-validation
tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-3, 1e-4],
                     'C': [1, 10, 100, 1000]}]

scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(SVC(), tuned_parameters, cv=5,
                       scoring='%s_macro' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for precision
# C:\Users\ChiefGuti\Miniconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ChiefGuti\Miniconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ChiefGuti\Miniconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ChiefGuti\Miniconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ChiefGuti\Miniconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ChiefGuti\Miniconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ChiefGuti\Miniconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ChiefGuti\Miniconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ChiefGuti\Miniconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ChiefGuti\Miniconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ChiefGuti\Miniconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ChiefGuti\Miniconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ChiefGuti\Miniconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ChiefGuti\Miniconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ChiefGuti\Miniconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ChiefGuti\Miniconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ChiefGuti\Miniconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ChiefGuti\Miniconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ChiefGuti\Miniconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ChiefGuti\Miniconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ChiefGuti\Miniconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ChiefGuti\Miniconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ChiefGuti\Miniconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ChiefGuti\Miniconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ChiefGuti\Miniconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# dataTest=dataTest[1::2][:]

# %% [markdown]
# DataSetTest=zeros((len(dataTest[:,0]),2))
# NormData(DataSetTest,dataTest)

# %% [markdown]
# CodeWordT=[]
# for i in range(len(CodeTest)):
#     CodeWordT.append(str(int(CodeTest[i])))
# WordT=[]
# for i in INT:
#     WordT.append(CodeWordT[i]+CodeWordT[i+1]+CodeWordT[i+2]+CodeWordT[i+3])

# %% [markdown]
# MapT=zeros(len(WordT))
# ColorMap(WordT,MapT,16)

# %% [markdown]
# scatter(dataTest[:,0]/max(dataTest[:,0]),dataTest[:,1]/max(dataTest[:,1]),c=MapT,s=1)
# colorbar()
# grid(True)

# %% [markdown]
# ## Predict on data

# %%
y_prediction= svclassifier.predict(X_test)

# %%
print(confusion_matrix(y_test,y_prediction))
print(classification_report(y_test,y_prediction))
# Out:
# [[85  0  0 ...,  0  0  0]
#  [ 0 78  0 ...,  0  0  0]
#  [ 0  0 90 ...,  0  0  0]
#  ...,
#  [ 0  0  0 ..., 93  0  0]
#  [ 0  0  0 ...,  0 84  0]
#  [ 0  0  0 ...,  0  0 80]]
#              precision    recall  f1-score   support
#
#         0.0       0.93      0.88      0.90        97
#         1.0       0.83      0.86      0.84        91
#         2.0       0.87      0.92      0.89        98
#         3.0       0.84      0.89      0.87        84
#         4.0       0.82      0.86      0.84        92
#         5.0       0.88      0.86      0.87        95
#         6.0       0.88      0.92      0.90        98
#         7.0       0.96      0.89      0.93       118
#         8.0       0.91      0.86      0.88       112
#         9.0       0.91      0.98      0.95        98
#        10.0       0.90      0.90      0.90       100
#        11.0       0.92      0.98      0.95        84
#        12.0       0.83      0.93      0.88       101
#        13.0       0.90      0.92      0.91       109
#        14.0       0.83      0.89      0.86        98
#        15.0       0.89      0.86      0.88        94
#        16.0       0.91      0.92      0.92       106
#        17.0       0.89      0.92      0.90       101
#        18.0       0.88      0.85      0.86       108
#        19.0       0.87      0.91      0.89       116
#        20.0       0.87      0.85      0.86        72
#        21.0       0.91      0.84      0.87        97
#        22.0       0.95      0.92      0.93       120
#        23.0       0.90      0.84      0.87       112
#        24.0       0.88      0.91      0.89       118
#        25.0       0.94      0.88      0.91        95
#        26.0       0.92      0.91      0.91       109
#        27.0       0.92      0.90      0.91        96
#        28.0       0.89      0.80      0.85       112
#        29.0       0.92      0.88      0.90        99
#        30.0       0.89      0.81      0.85        88
#        31.0       0.83      0.87      0.85        84
#        32.0       0.97      0.81      0.89        95
#        33.0       0.84      0.88      0.86       107
#        34.0       0.92      0.83      0.88       103
#        35.0       0.87      0.91      0.89        88
#        36.0       0.88      0.93      0.90       107
#        37.0       0.91      0.87      0.89       110
#        38.0       0.92      0.95      0.93       112
#        39.0       0.90      0.91      0.91       104
#        40.0       0.88      0.85      0.87       103
#        41.0       0.89      0.92      0.91       114
#        42.0       0.93      0.92      0.93       117
#        43.0       0.89      0.99      0.94        97
#        44.0       0.88      0.89      0.88       111
#        45.0       0.89      0.86      0.87       104
#        46.0       0.87      0.90      0.89       113
#        47.0       0.92      0.85      0.88        84
#        48.0       0.90      0.88      0.89        97
#        49.0       0.91      0.89      0.90       109
#        50.0       0.85      0.88      0.86       109
#        51.0       0.91      0.86      0.89       123
#        52.0       0.86      0.96      0.91       108
#        53.0       0.84      0.86      0.85       105
#        54.0       0.84      0.92      0.88        87
#        55.0       0.87      0.92      0.89        95
#        56.0       0.90      0.91      0.90       107
#        57.0       0.91      0.87      0.89       115
#        58.0       0.95      0.89      0.92       111
#        59.0       0.85      0.94      0.89       105
#        60.0       0.93      0.93      0.93       120
#        61.0       0.92      0.87      0.89       107
#        62.0       0.89      0.90      0.90        93
#        63.0       0.90      0.87      0.88        92
#
# avg / total       0.89      0.89      0.89      6554

# %%
format(BER(y_test,y_prediction),'.3e')
# Out:
# '1.085e-01'

# %%
scatter(X_test[:,0],X_test[:,1],c=y_prediction,s=1)
colorbar()
grid(True)
